# %% [markdown]
# ## 4.9.1.6 Preparing data for merge

# %% [markdown]
# ## 4.9.1.6 Preparing data for merge

# %%
# import libraries
import pandas as pd
import numpy as np
import os

# %%
# import customer data
path = r'C:\Users\darii\Documents\10-2023 Instacart Basket Analysis'
customers=pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'customers_4.9.1_ZA.pkl'))

# %%
customers.head(10)
# Out:
#   user_id      name   surname  gender           state  age date_joined  \
# 0   26711   Deborah  Esquivel  Female        Missouri   48  2017-01-01
# 1   33890  Patricia      Hart  Female      New Mexico   36  2017-01-01
# 2   65803   Kenneth    Farley    Male           Idaho   35  2017-01-01
# 3  125935  Michelle     Hicks  Female            Iowa   40  2017-01-01
# 4  130797       Ann   Gilmore  Female        Maryland   26  2017-01-01
# 5  133128   Cynthia     Noble  Female        Kentucky   43  2017-01-01
# 6  152052     Chris    Walton    Male         Montana   20  2017-01-01
# 7  168851    Joseph   Hickman    Male  South Carolina   30  2017-01-01
# 8   69965    Jeremy      Vang    Male           Texas   47  2017-01-01
# 9   82820     Shawn     Chung    Male        Virginia   26  2017-01-01
#
#    n_dependants   status  income
# 0             3  married  165665
# 1             0   single   59285
# 2             2  married   99568
# 3             0   single   42049
# ...

# %%
customers.dtypes
# Out:
# user_id                 object
# name                    object
# surname                 object
# gender                  object
# state                   object
# age                      int64
# date_joined     datetime64[ns]
# n_dependants             int64
# status                  object
# income                   int64
# dtype: object

# %%
customers['age'] = customers['age'].astype('int8')

# %%
customers['income'] = customers['income'].astype('int32')

# %%
customers.info
# Out:
# <bound method DataFrame.info of        user_id      name   surname  gender           state  age date_joined  \
# 0        26711   Deborah  Esquivel  Female        Missouri   48  2017-01-01
# 1        33890  Patricia      Hart  Female      New Mexico   36  2017-01-01
# 2        65803   Kenneth    Farley    Male           Idaho   35  2017-01-01
# 3       125935  Michelle     Hicks  Female            Iowa   40  2017-01-01
# 4       130797       Ann   Gilmore  Female        Maryland   26  2017-01-01
# ...        ...       ...       ...     ...             ...  ...         ...
# 206204  168073      Lisa      Case  Female  North Carolina   44  2020-04-01
# 206205   49635    Jeremy   Robbins    Male          Hawaii   62  2020-04-01
# 206206  135902     Doris  Richmond  Female        Missouri   66  2020-04-01
# 206207   81095      Rose   Rollins  Female      California   27  2020-04-01
# 206208   80148   Cynthia     Noble  Female        New York   55  2020-04-01
#
# ...

# %%
# import ords prods data
path = r'C:\Users\darii\Documents\10-2023 Instacart Basket Analysis'
orders_products_merged=pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged_4.9.1_cleaned.pkl'))

# %%
orders_products_merged.head(10)
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
# 5           1  Chocolate Sandwich Cookies        61             19     5.8
# 6           1  Chocolate Sandwich Cookies        61             19     5.8
# 7           1  Chocolate Sandwich Cookies        61             19     5.8
# 8           1  Chocolate Sandwich Cookies        61             19     5.8
# 9           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id user_id  order_number  orders_day_of_week  order_hour_of_day  ...  \
# ...

# %%
orders_products_merged.dtypes
# Out:
# product_id                         int64
# product_name                      object
# aisle_id                           int64
# department_id                      int64
# prices                           float64
# order_id                           int64
# user_id                           object
# order_number                       int64
# orders_day_of_week                 int64
# order_hour_of_day                  int64
# days_since_prior_order           float64
# new_customer                        bool
# add_to_cart_order                  int64
# reordered                          int64
# price_range_loc                   object
# busiest_day                       object
# busiest_days                      object
# busiest_period_of_day             object
# max_order                          int64
# loyalty_flag                      object
# mean_spend                       float64
# spender_flag                      object
# median_days_since_prior_order    float64
# ...

# %%
orders_products_merged['product_id'] = orders_products_merged['product_id'].astype('int32')
orders_products_merged['aisle_id'] = orders_products_merged['aisle_id'].astype('int8')
orders_products_merged['department_id'] = orders_products_merged['department_id'].astype('int8')
orders_products_merged['order_id'] = orders_products_merged['order_id'].astype('int32')
orders_products_merged['order_number'] = orders_products_merged['order_number'].astype('int32')
orders_products_merged['orders_day_of_week'] = orders_products_merged['orders_day_of_week'].astype('int8')
orders_products_merged['order_hour_of_day'] = orders_products_merged['order_hour_of_day'].astype('int8')
orders_products_merged['add_to_cart_order'] = orders_products_merged['add_to_cart_order'].astype('int8')
orders_products_merged['reordered'] = orders_products_merged['reordered'].astype('int8')
orders_products_merged['max_order'] = orders_products_merged['max_order'].astype('int8')

# %%
orders_products_merged.info
# Out:
# <bound method DataFrame.info of           product_id                product_name  aisle_id  department_id  \
# 0                  1  Chocolate Sandwich Cookies        61             19
# 1                  1  Chocolate Sandwich Cookies        61             19
# 2                  1  Chocolate Sandwich Cookies        61             19
# 3                  1  Chocolate Sandwich Cookies        61             19
# 4                  1  Chocolate Sandwich Cookies        61             19
# ...              ...                         ...       ...            ...
# 32404854       49688      Fresh Foaming Cleanser        73             11
# 32404855       49688      Fresh Foaming Cleanser        73             11
# 32404856       49688      Fresh Foaming Cleanser        73             11
# 32404857       49688      Fresh Foaming Cleanser        73             11
# 32404858       49688      Fresh Foaming Cleanser        73             11
#
# ...

# %%
orders_products_merged.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged_4.9.1_cleaned.pkl'))

# %%
customers.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'customers_4.9.1_cleaned.pkl'))
